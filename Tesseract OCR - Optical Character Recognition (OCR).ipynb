# %% [markdown]
# # Tesseract OCR - Optical Character Recognition (OCR) engine
# ---
#
# ### Extracting patient information, claim numbers, diagnoses (ICD codes), procedures (CPT/HCPCS), and billing details from: HCFA/CMS-1500 forms (physician claims)

# %% [markdown]
# __Use case:__ Healthcare document management systems can use pytesseract to make scanned documents searchable by extracting metadata and indexing the
# text for quick lookup (e.g., searching for a patient ID or diagnosis).

# %% [markdown]
# Extracting patient information, claim numbers, diagnoses (ICD codes), procedures (CPT/HCPCS), and billing details from:
#
# * HCFA/CMS-1500 forms (physician claims)
#
# * UB-04 forms (hospital claims)

# %%
import pytesseract
from PIL import Image

# %% [markdown]
# # Import Synthetic Claim Form

# %%
import_image = Image.open('HCFA-CMS-1500 forms-syntetic.png')
import_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1536>

# %%
text = pytesseract.image_to_string(import_image)
text
# Out:
# 'HEALTH INSURANCE CLAIM FORM PICA\nAPPROVED BY NATIONAL UNIFORM CLAIM COMMITTIT EE (NCC) 1500402-12)\n\n1 PATIENT 10) ENNEDICARE 2. CARBB INAWME 5 M8 Pi 1D | €F TAGE [AMAIS] 6 IPATENT\'S SIE:\na " HbARY!\nMEDICARE 123456789A 0110111950..|M) | JOHN D DOE\n7 PATIENT\'S INSUREDS NAME11) 4 I PATIENT S, OMEGPOMATION 5 MB SO;COMY [ESEEVED] FOR NUCE USE\n1 AVERRAT. YiERt MOK UN DYGT HIV)\nJOHN D DOE IROSEMPLOTIOR NUCE USE. ID AB13345678\n8 INSURED\'S ADDRESS 5. BNaRe EREWAL.C/ EVIPLDERIRY|| 6 MODIFIERIS) [OH HE (WAIT MIMEISF.\n1234 MAIN-ST AB12345678\nANY TOWN 63. ee, 22 races EMPLOYMENTIOFFIER\nUSA. 12845\nc 2123456789\n9 ADDRESS AINPHORE), 5 INO- IN OMFBUPS ANY BEX\nWADI 1S OSIBRIUTLUR | 22 PRIOR AUTHORIZATION AUMBER,\nAB12345678\n1 [PATIENTS MARITAL STAIUS DITE-IMI7TOTH (OCE) {PESERVED FOR NUCE USE) 9999999999\n[no y¥ 23, PRIOR AUTHORIZATION NUMBER\n8 OTHER INSURED\'S (GREATTOW) 100. (]VIGRMP NO\n(KONE) Gsiesm =] No 24 ENPI CRILE SERVICES,\n9D. NOT (ENENEY LINE) 19 (CD NGWaIcTs) ——\nSAMA
# ...
